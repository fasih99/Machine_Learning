# %%
import pandas as pd
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../DATA/kc_house_data.csv')

# %%
df.isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21592  False  False  False     False      False        False     False
# 21593  False  False  False     False      False        False     False
# 21594  False  False  False     False      False        False     False
# 21595  False  False  False     False      False        False     False
# 21596  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='price',y='sqft_living', data=df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='bedrooms',y='price',data =df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='grade',y='price',data =df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data =df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data =df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='price',data=df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values('price',ascending=False).head(30)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df)*0.01
# Out:
# 215.97

# %%
bottom_99 = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',hue='price', edgecolor=None, alpha=0.2, palette='RdYlGn',data=bottom_99)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront',y='price', data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df= df.drop('id',axis=1)

# %%
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df['date']
# Out:
# 0        10/13/2014
# 1         12/9/2014
# 2         2/25/2015
# 3         12/9/2014
# 4         2/18/2015
#             ...
# 21592     5/21/2014
# 21593     2/23/2015
# 21594     6/23/2014
# 21595     1/16/2015
# 21596    10/15/2014
# Name: date, Length: 21597, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df['year'] = df['date'].apply(lambda date: date.year)
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21592 2014-05-21  360000.0         3       2.50         1530      1131
# 21593 2015-02-23  400000.0         4       2.50         2310      5813
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21595 2015-01-16  400000.0         3       2.50         1600      2388
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
df.corr()['price']
# Out:
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.266398
# view             0.397370
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# sqft_basement    0.323799
# yr_built         0.053953
# yr_renovated     0.126424
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# year             0.003727
# month           -0.009928
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='month',y='price',data=df)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
df.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df = df.drop('date', axis=1)

# %%
df
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# ...

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# month           -0.009928
# year             0.003727
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
df.drop('zipcode',axis=1)
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21592  360000.0         3       2.50         1530      1131     3.0
# 21593  400000.0         4       2.50         2310      5813     2.0
# 21594  402101.0         2       0.75         1020      1350     2.0
# 21595  400000.0         3       2.50         1600      2388     2.0
# 21596  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# ...

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1951        1
# 1959        1
# 1948        1
# 1954        1
# 1944        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# 0      13110
# 600      221
# 700      218
# 500      214
# 800      206
#        ...
# 518        1
# 374        1
# 784        1
# 906        1
# 248        1
# Name: sqft_basement, Length: 306, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(y=df['price'],x=df['sqft_living'])
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
df['price'].sort_values(ascending=False)
# Out:
# 7245     7700000.0
# 3910     7060000.0
# 9245     6890000.0
# 4407     5570000.0
# 1446     5350000.0
#            ...
# 2139       82500.0
# 8267       82000.0
# 16184      81000.0
# 465        80000.0
# 15279      78000.0
# Name: price, Length: 21597, dtype: float64

# %%
bottom_99 = df.sort_values('price',ascending=False).iloc[200:] # removing outliers

# %%
bottom_99
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 15025  2000000.0         3       3.25         2610     16387     2.0
# 19200  2000000.0         5       4.25         6490     10862     2.0
# 6685   2000000.0         2       2.50         3900    920423     2.0
# 21     2000000.0         3       2.75         3050     44867     1.0
# 10457  2000000.0         4       3.75         2870      4500     2.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# ...

# %%
X = bottom_99.drop('price',axis=1).values
y = bottom_99['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

# %%
# Out:
# array([[3.000e+00, 1.000e+00, 1.180e+03, ..., 5.650e+03, 2.014e+03,
#         1.000e+01],
#        [3.000e+00, 2.250e+00, 2.570e+03, ..., 7.639e+03, 2.014e+03,
#         1.200e+01],
#        [2.000e+00, 1.000e+00, 7.700e+02, ..., 8.062e+03, 2.015e+03,
#         2.000e+00],
#        ...,
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 2.007e+03, 2.014e+03,
#         6.000e+00],
#        [3.000e+00, 2.500e+00, 1.600e+03, ..., 1.287e+03, 2.015e+03,
#         1.000e+00],
#        [2.000e+00, 7.500e-01, 1.020e+03, ..., 1.357e+03, 2.014e+03,
#         1.000e+01]])

# %%
model= Sequential()

layer1=model.add(Dense(20,activation='relu'))
layer1=model.add(Dense(20,activation='relu'))
layer1=model.add(Dense(20,activation='relu'))
layer1=model.add(Dense(20,activation='relu'))


model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train,y=y_train,
          validation_data = (X_test,y_test),
          batch_size=128,
          epochs=600)
# Out:
# Epoch 1/600
# 118/118 [==============================] - 1s 2ms/step - loss: 349661986816.0000 - val_loss: 359356334080.0000
# Epoch 2/600
# 118/118 [==============================] - 0s 1ms/step - loss: 348813852672.0000 - val_loss: 356264280064.0000
# Epoch 3/600
# 118/118 [==============================] - 0s 1ms/step - loss: 336649486336.0000 - val_loss: 327255818240.0000
# Epoch 4/600
# 118/118 [==============================] - 0s 1ms/step - loss: 275739049984.0000 - val_loss: 223717916672.0000
# Epoch 5/600
# 118/118 [==============================] - 0s 1ms/step - loss: 146735988736.0000 - val_loss: 88775254016.0000
# Epoch 6/600
# 118/118 [==============================] - 0s 1ms/step - loss: 64491802624.0000 - val_loss: 58561671168.0000
# Epoch 7/600
# 118/118 [==============================] - 0s 1ms/step - loss: 55997898752.0000 - val_loss: 57282699264.0000
# Epoch 8/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 140367.82644833246

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 93790.64874537577

# %%
bottom_99['price'].describe()
# Out:
# count    2.139700e+04
# mean     5.194684e+05
# std      2.876656e+05
# min      7.800000e+04
# 25%      3.200000e+05
# 50%      4.500000e+05
# 75%      6.350000e+05
# max      2.000000e+06
# Name: price, dtype: float64

# %%
  5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7649459608217279

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %%
test_house = df.drop('price',axis=1).head(50)

# %%
test_house = scaler.transform(test_house)
# Out:
# /usr/local/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
test_house
# Out:
# array([[2.00000000e-01, 7.14285714e-02, 1.11424542e-01, 4.40617930e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.00000000e-01,
#         3.33333333e-01, 1.12375533e-01, 0.00000000e+00, 4.78260870e-01,
#         0.00000000e+00, 8.93939394e-01, 5.71497507e-01, 2.17607973e-01,
#         1.74550176e-01, 8.92732773e-03, 0.00000000e+00, 8.18181818e-01],
#        [2.00000000e-01, 2.50000000e-01, 3.07475317e-01, 5.77355502e-03,
#         4.00000000e-01, 0.00000000e+00, 0.00000000e+00, 5.00000000e-01,
#         3.33333333e-01, 2.53200569e-01, 1.40350877e-01, 4.43478261e-01,
#         9.88089330e-01, 6.26262626e-01, 9.08959305e-01, 1.66112957e-01,
#         2.39473196e-01, 1.24793291e-02, 0.00000000e+00, 1.00000000e+00],
#        [1.00000000e-01, 7.14285714e-02, 5.35966150e-02, 8.14241321e-03,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.00000000e-01,
#         2.22222222e-01, 5.40540541e-02, 0.00000000e+00, 2.86956522e-01,
# ...

# %%
model_predictions = model.predict(test_house)

# %%
df_model_predictions = pd.DataFrame( model_predictions, columns = ['Model Predictions'])

# %%
test_data=df['price'].head(50)

# %%
df2 = pd.concat([df_model_predictions,test_data],axis=1)
df2
# Out:
#     Model Predictions      price
# 0        2.687695e+05   221900.0
# 1        6.348015e+05   538000.0
# 2        4.758662e+05   180000.0
# 3        4.321239e+05   604000.0
# 4        4.571515e+05   510000.0
# 5        1.245728e+06  1230000.0
# 6        2.644493e+05   257500.0
# 7        2.382123e+05   291850.0
# 8        3.563846e+05   229500.0
# 9        3.337200e+05   323000.0
# 10       7.035035e+05   662500.0
# 11       3.820651e+05   468000.0
# 12       6.001196e+05   310000.0
# 13       3.683129e+05   400000.0
# 14       6.628482e+05   530000.0
# 15       9.355206e+05   650000.0
# 16       4.802422e+05   395000.0
# 17       5.288227e+05   485000.0
# 18       2.766405e+05   189000.0
# 19       2.311236e+05   230000.0
# 20       4.406197e+05   385000.0
# 21       9.683484e+05  2000000.0
# 22       3.372979e+05   285000.0
# 23       2.124849e+05   252700.0
# 24       4.214492e+05   329000.0
# 25       2.194511e+05   233000.0
# 26       7.948640e+05   937000.0
# ...

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=df2['price'],y=df2['Model Predictions'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Model Predictions'>

# %%
plt.figure(figsize=(10,6))
plt.scatter(df2['price'],df2['Model Predictions'])
plt.plot(y_test,y_test,'r')
